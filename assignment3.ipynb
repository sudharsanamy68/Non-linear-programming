# %%
#Example 1
import matplotlib.pyplot as plt

import numpy as np

f1 = lambda x : (x - 1) ** 4 + x ** 2

from scipy.optimize import minimize_scalar

res = minimize_scalar(f1, method='brent')

print('xmin: %.02f, fval: %.02f, iter: %d' % (res.x, res.fun, res.nit))

x = np.linspace(res.x - 0.5, res.x + 0.5, 100)

y = [f1(val) for val in x]

plt.plot(x, y, color='blue', label='f1')

plt.scatter(res.x, res.fun, color='red', marker='x', label='opt')

plt.grid()

plt.legend(loc=1)
# Out:
# xmin: 0.41, fval: 0.29, iter: 12

# %%
#Example 2
import matplotlib.pyplot as plt

import numpy as np

f1 = lambda x : np.exp(-(x - 0.5)**2)

from scipy.optimize import minimize_scalar

res = minimize_scalar(f1, method='brent')

print('xmin: %.02f, fval: %.02f, iter: %d' % (res.x, res.fun, res.nit))

x = np.linspace(res.x - 0.5, res.x + 0.5, 100)

y = [f1(val) for val in x]

plt.plot(x, y, color='blue', label='f1')

plt.scatter(res.x, res.fun, color='red', marker='x', label='opt')

plt.grid()

plt.legend(loc=1)
# Out:
# xmin: 74.40, fval: 0.00, iter: 35

# %%
#1
import matplotlib.pyplot as plt
import numpy as np
 
f1 = lambda x: 4*x**2+3*x**2+5*x**2+6*x*x+x*x-3*x-2*x+15
from scipy.optimize import minimize_scalar
res = minimize_scalar(f1, method='brent')
print(f'xmin: {res.x:.02f}, fval: {res.fun:.02f}, iter: {res.nit}')
x = np.linspace(res.x - 0.5, res.x + 0.5, 100)
y = [f1(val) for val in x]

plt.plot(x, y, color='blue', label='f1')
plt.scatter(res.x, res.fun, color='red', marker='x', label='opt')
plt.grid()
plt.legend(loc=1)
plt.xlabel('x')
plt.ylabel('f1(x)')
plt.title('Minimization of f1(x)')
plt.show()
# Out:
# xmin: 0.13, fval: 14.67, iter: 24

# %%
#1
import matplotlib.pyplot as plt
import numpy as np
 
 
f1 = lambda x: x**2
from scipy.optimize import minimize_scalar
res = minimize_scalar(f1, method='brent')
print(f'xmin: {res.x:.02f}, fval: {res.fun:.02f}, iter: {res.nit}')
x = np.linspace(res.x - 0.5, res.x + 0.5, 100)
y = [f1(val) for val in x]

plt.plot(x, y, color='blue', label='f1')
plt.scatter(res.x, res.fun, color='red', marker='x', label='opt')
plt.grid()
plt.legend(loc=1)
plt.xlabel('x')
plt.ylabel('f1(x)')
plt.title('Minimization of f1(x)')
plt.show()
# Out:
# xmin: 0.00, fval: 0.00, iter: 4

# %%
#2
import matplotlib.pyplot as plt
import numpy as np
 
f1 = lambda x: 3*x**3 - 6*x**2
from scipy.optimize import minimize_scalar
res = minimize_scalar(f1, method='brent')
print(f'xmin: {res.x:.02f}, fval: {res.fun:.02f}, iter: {res.nit}')
x = np.linspace(res.x - 0.5, res.x + 0.5, 100)
y = [f1(val) for val in x]

plt.plot(x, y, color='blue', label='f1')
plt.scatter(res.x, res.fun, color='red', marker='x', label='opt')
plt.grid()
plt.legend(loc=1)
plt.xlabel('x')
plt.ylabel('f1(x)')
plt.title('Minimization of f1(x)')
plt.show()
# Out:
# xmin: 1.33, fval: -3.56, iter: 12

# %%
#3
import matplotlib.pyplot as plt
import numpy as np

f1 = lambda x: 25*x**2-8*x*x+x**2
from scipy.optimize import minimize_scalar
res = minimize_scalar(f1, method='brent')
print(f'xmin: {res.x:.02f}, fval: {res.fun:.02f}, iter: {res.nit}')
x = np.linspace(res.x - 0.5, res.x + 0.5, 100)
y = [f1(val) for val in x]
 
plt.plot(x, y, color='blue', label='f1')
plt.scatter(res.x, res.fun, color='red', marker='x', label='opt')
plt.grid()
plt.legend(loc=1)
plt.xlabel('x')
plt.ylabel('f1(x)')
plt.title('Minimization of f1(x)')
plt.show()
# Out:
# xmin: 0.00, fval: 0.00, iter: 4
